# %% [markdown]
# # Module 6: Inferential Statisitics and Visualization

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
print("Setup Complete")
# Out:
# Setup Complete

# %%
# Read the data into DataFrame from the CSV file
file_path = '../data/fifa.csv'
fifa_df = pd.read_csv(file_path, index_col='Date', parse_dates=True)

# Print the first 5 rows of the data
fifa_df.head()
# Out:
#              ARG  BRA   ESP   FRA  GER  ITA
# Date
# 1993-08-08   5.0  8.0  13.0  12.0  1.0  2.0
# 1993-09-23  12.0  1.0  14.0   7.0  5.0  2.0
# 1993-10-22   9.0  1.0   7.0  14.0  4.0  3.0
# 1993-11-19   9.0  4.0   7.0  15.0  3.0  1.0
# 1993-12-23   8.0  3.0   5.0  15.0  1.0  2.0

# %%
# TODO: Plot the data
# Set the figure size
plt.figure(figsize=(16, 6))

# Line chart showing how FIFA rankings evolved over time
sns.lineplot(data=fifa_df)
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# ## Load a Spotify top five songs dataset
#
# Tracks globally the daily streams on the music service Spotiy of the top five songs.

# %%
# Load data for the next exercise
file_path = '../data/spotify.csv'
spotify_df = pd.read_csv(file_path, index_col='Date', parse_dates=True)

# Print the first 5 rows of the data
spotify_df.tail()
# Out:
#             Shape of You  Despacito  Something Just Like This    HUMBLE.  \
# Date
# 2018-01-05       4492978  3450315.0                 2408365.0  2685857.0
# 2018-01-06       4416476  3394284.0                 2188035.0  2559044.0
# 2018-01-07       4009104  3020789.0                 1908129.0  2350985.0
# 2018-01-08       4135505  2755266.0                 2023251.0  2523265.0
# 2018-01-09       4168506  2791601.0                 2058016.0  2727678.0
#
#             Unforgettable
# Date
# 2018-01-05      2869783.0
# 2018-01-06      2743748.0
# 2018-01-07      2441045.0
# 2018-01-08      2622693.0
# 2018-01-09      2627334.0

# %%
# Line chart showing the number of streams of each song over time
sns.lineplot(data=spotify_df)
# Out:
# <Axes: xlabel='Date'>

# %%
# Set the figure size
plt.figure(figsize=(16, 6))

# Set the title and labels
plt.title("Daily Global Streams of Popular Songs in 2017-2018")

# Create line plot of spotify data
sns.lineplot(data=spotify_df)
# Out:
# <Axes: title={'center': 'Daily Global Streams of Popular Songs in 2017-2018'}, xlabel='Date'>

# %%
# TODO: Plot subsets of the data

# Create a list of the songs to plot
list(spotify_df.columns)
# Out:
# ['Shape of You',
#  'Despacito',
#  'Something Just Like This',
#  'HUMBLE.',
#  'Unforgettable']

# %%
# Plot only two of the songs
plt.figure(figsize=(14, 6))

# Set the title and labels
plt.title("Daily Global Streams of Popular Songs in 2017-2018")
plt.xlabel("Date")
plt.ylabel("Number of Streams (in 10 millions)")

# Create line plot of Shape of You data
sns.lineplot(data=spotify_df['Shape of You'], label="Shape of You")

# Create line plot of Despacito data
sns.lineplot(data=spotify_df['Despacito'], label="Despacito")
# Out:
# <Axes: title={'center': 'Daily Global Streams of Popular Songs in 2017-2018'}, xlabel='Date', ylabel='Number of Streams (in 10 millions)'>

# %% [markdown]
# ### Task: Understand Musuem Attendance

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
print("Setup Complete")
# Out:
# Setup Complete

# %%
# Load data 
file_path = '../data/museum_visitors.csv'
musuem_df = pd.read_csv(file_path, index_col='Date', parse_dates=True)

# Print the first 5 rows of the data
musuem_df.head()
# Out:
#             Avila Adobe  Firehouse Museum  Chinese American Museum  \
# Date
# 2014-01-01        24778              4486                     1581
# 2014-02-01        18976              4172                     1785
# 2014-03-01        25231              7082                     3229
# 2014-04-01        26989              6756                     2129
# 2014-05-01        36883             10858                     3676
#
#             America Tropical Interpretive Center
# Date
# 2014-01-01                                  6602
# 2014-02-01                                  5029
# 2014-03-01                                  8129
# 2014-04-01                                  2824
# 2014-05-01                                 10694

# %% [markdown]
# The Firehouse museum claims they ran an event in 2014 that brought a big number of visitors, and that they should extra budget to run a similar event this year.
#
# Task: Show the museum board how the event compared to regular traffic at each museum.
# - Create a `lineplot chart` that shows how the number of visitors changed on each museum overtime
# - Provide a title for the plot

# %%
# Set the width and height of the figure
plt.figure(figsize=(16, 6))

# Set the title
plt.title("Number of Visitors to Each Museum Over Time")

# Line chart showing the number of visitors to each museum over time
sns.lineplot(data=musuem_df)
# Out:
# <Axes: title={'center': 'Number of Visitors to Each Museum Over Time'}, xlabel='Date'>

# %% [markdown]
# ### Assess Seasonality
# When meeting with the employees of the `Avila Adobe`, you hear that one major point pain point is that the number of the visitors varies greatly with the season.
#
# Part A:
# - Create a `line chart` that shows how the number of visitors to the `Avila Adobe` has evolved over time
# - Replace `inf` with `nan`, and then fill them in with `0`

# %%
import numpy as np

# Replace inf with nan
musuem_df = musuem_df.replace([np.inf, -np.inf], np.nan)

# Use fillna() to replace nan with the previous value in the column
musuem_df = musuem_df.fillna(0)

# Plot the data
# Set the width and height of the figure
plt.figure(figsize=(14, 6))

# Set the title and label
plt.title("Monthly Attendance of Avila Adobe (2014-2019)")
plt.xlabel("Date")
plt.ylabel("Number of Visitors")

# Line chart showing the number of visitors to Avila Adobe over time
sns.lineplot(data=musuem_df['Avila Adobe'])
# Out:
# <Axes: title={'center': 'Monthly Attendance of Avila Adobe (2014-2019)'}, xlabel='Date', ylabel='Number of Visitors'>

# %% [markdown]
# ## Bar Plots
#
# Dataset: Use Department of Transportation that tracks filght delays

# %%
# Load data
file_path = '../data/flight_delays.csv'

# Read the data into DataFrame
flight_delay_df = pd.read_csv(file_path, index_col='Month')

# Print the first 5 rows of the data
flight_delay_df.head()
# Out:
#              AA        AS         B6        DL         EV         F9  \
# Month
# 1      6.955843 -0.320888   7.347281 -2.043847   8.537497  18.357238
# 2      7.530204 -0.782923  18.657673  5.614745  10.417236  27.424179
# 3      6.693587 -0.544731  10.741317  2.077965   6.730101  20.074855
# 4      4.931778 -3.009003   2.780105  0.083343   4.821253  12.640440
# 5      5.173878 -1.716398  -0.709019  0.149333   7.724290  13.007554
#
#              HA         MQ         NK         OO        UA        US  \
# Month
# 1      3.512640  18.164974  11.398054  10.889894  6.352729  3.107457
# 2      6.029967  21.301627  16.474466   9.588895  7.260662  7.114455
# 3      3.468383  11.018418  10.039118   3.181693  4.892212  3.330787
# 4      0.011022   5.131228   8.766224   3.223796  4.376092  2.660290
# 5      0.826426   5.466790  22.397347   4.141162  6.827695  0.681605
#
#              VX        WN
# Month
# 1      1.420702  3.389466
# 2      7.784410  3.501363
# 3      5.348207  3.263341
# ...

# %%
# Chart a bar plot 
plt.figure(figsize=(14, 6))

# Set the title and labels
plt.title("Average Arrival Delay for Spirit Airlines Flights, by Month")
plt.ylabel("Arrival delay (in minutes)")

# Plot the bar chart
sns.barplot(x=flight_delay_df.index, y=flight_delay_df['NK'])
# Out:
# <Axes: title={'center': 'Average Arrival Delay for Spirit Airlines Flights, by Month'}, xlabel='Month', ylabel='Arrival delay (in minutes)'>

# %% [markdown]
# ## Heat Maps in Seaborn

# %%
# Plot heatmap for all data
plt.figure(figsize=(14, 6))

# Set the title and labels
plt.title("Average Arrival Delay for Each Airline, by Month")
plt.xlabel("Airline")

# Plot the heatmap
sns.heatmap(data=flight_delay_df, annot=True)
# Out:
# <Axes: title={'center': 'Average Arrival Delay for Each Airline, by Month'}, ylabel='Month'>

# %% [markdown]
# ## Scatter Plots
#
# ### Load the Dataset
# We will use a (synthetic) dataset of medical insurance charges: `data/insurance.csv`

# %%
# Load the data into DataFrame
file_path = '../data/insurance.csv'
insurance_df = pd.read_csv(file_path)

# Print the first 5 rows of the data
insurance_df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
# TODO: Use a scatter plot in Seaborn to create a scatter plot
# Set the width and height of the figure
plt.figure(figsize=(14, 6))
# Set the title
plt.title("Insurance Cost vs. Age")
# Set the x-axis label
plt.xlabel("Body-Mass Index (BMI)")
plt.ylabel("Insurance Charges")
# Create scatter plot of bmi vs. charges
sns.scatterplot(x=insurance_df['bmi'], y=insurance_df['charges'])
# Out:
# <Axes: title={'center': 'Insurance Cost vs. Age'}, xlabel='Body-Mass Index (BMI)', ylabel='Insurance Charges'>

# %%
# NOTE: The plot suggests there's a positive correlation between BMI and insurance charges.
# TODO: To double check the strength of this relationship, add a regression line to the plot.
# Set the width and height of the figure
plt.figure(figsize=(14, 6))
# Set the title
plt.title("Insurance Cost vs. BMI")
# Create scatter plot of bmi vs. charges
sns.regplot(x=insurance_df['bmi'], y=insurance_df['charges'])
# Out:
# <Axes: title={'center': 'Insurance Cost vs. BMI'}, xlabel='bmi', ylabel='charges'>

# %% [markdown]
# ### Color-coded Scatter Plots
# The are good when you need to display the correlation between more than two variables
#
# We want to understand how `smokers` affects the relationship between `bmi` and `charges`

# %%
# TODO: We want to understand how smokers affect the relationship between BMI and insurance costs.
# Set the width and height of the figure
plt.figure(figsize=(14, 6))
# Set the title
plt.title("Insurance Cost vs. BMI")
# Create scatter plot of bmi vs. charges
sns.scatterplot(x=insurance_df['bmi'], y=insurance_df['charges'], hue=insurance_df['smoker'])
# Out:
# <Axes: title={'center': 'Insurance Cost vs. BMI'}, xlabel='bmi', ylabel='charges'>

# %%
# TODO: Fit a regression line to the scatter plots for smokers and non-smokers
# Set the width and height of the figure
plt.figure(figsize=(14, 6))
# Create scatter plot of bmi vs. charges
sns.lmplot(x="bmi", y="charges", hue="smoker", data=insurance_df)

# %%
# TODO: We can adapt the design of a sactter plot to feature a categorical variable (like "smoker") on the x-axis.
# Some people call this a Categorical Scatter Plot.
# Set the width and height of the figure
plt.figure(figsize=(14, 6))
# Set the title
plt.title("Insurance Cost vs. Smoking Status")
# Create scatter plot of smoking status vs. charges
sns.swarmplot(x=insurance_df['smoker'], y=insurance_df['charges'])
# Out:
# <Axes: title={'center': 'Insurance Cost vs. Smoking Status'}, xlabel='smoker', ylabel='charges'>
# /opt/miniconda3/envs/module6/lib/python3.12/site-packages/seaborn/categorical.py:3399: UserWarning: 16.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
